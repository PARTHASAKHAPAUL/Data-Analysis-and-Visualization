# %% [markdown]
# # 1. We should first experiment with artificially generated data. To that end, use the numpy routine numpy.random.multivariate_normal that generates points randomly by the multivariate Gauss distribution. In that case, the subroutine for task
# 1 has an interface as follows:
# Parameters
# mean center of the Gaussian
# cov covariance matrix
# nx number data points
# nt number test points
# Returns
# x set of random vectors of length nx (data points)
# t set of random vectors of length nt (test points)
# mu mean based on x
# Sgm covariance matrix based on x
#
# def getArtificialData(mean, cov, nx, nt):
# Note that this routine calls the random.multivariate_normal twice, i.e., for the
# data and test set. The vector mean and the matrix cov must be in R
# D and R
# D×D.
# The returned values mu and Sgm are computed by (9.19) and (9.20) in Murphy’s
# book. They should be similar to mean and cov, but are different, in general. This
# routine must be called for each class c. To get the test points of each class into one
# long vector use the numpy.concatenate function.

# %%
import numpy as np

def getArtificialData(mean, cov, nx, nt):
    x = np.random.multivariate_normal(mean, cov, nx)
    t = np.random.multivariate_normal(mean, cov, nt)
    mu = np.mean(x, axis=0)
    Sgm = np.cov(x, rowvar=False)
    return x, t, mu, Sgm

# example parameters for three classes
mean_class1 = [0, 0]
cov_class1 = [[2, 1], [1, 50]]
nx1, nt1 = 40, 10

mean_class2 = [7, 5]
cov_class2 = [[3, 1], [1, 3]]
nx2, nt2 = 80, 20

mean_class3 = [-5, 5]
cov_class3 = [[5, 2], [2, 3]]
nx3, nt3 = 20, 5

# generate data for class 1
x1, t1, mu1, Sgm1 = getArtificialData(mean_class1, cov_class1, nx1, nt1)

# generate data for class 2
x2, t2, mu2, Sgm2 = getArtificialData(mean_class2, cov_class2, nx2, nt2)

# generate data for class 3
x3, t3, mu3, Sgm3 = getArtificialData(mean_class3, cov_class3, nx3, nt3)

# combine the test points from both classes
test_points_combined = np.concatenate([t1, t2, t3], axis=0)


# print(x1.shape)
# print(x1)
# print(t1.shape)
# print(t1)
# print(mu1.shape)
# print(mu1)
# print(Sgm1.shape)
# print(Sgm1)
# print()
# print(x2.shape)
# print(x2)
# print(t2.shape)
# print(t2)
# print(mu2.shape)
# print(mu2)
# print(Sgm2.shape)
# print(Sgm2)
# print()
# print(x3.shape)
# print(x3)
# print(t3.shape)
# print(t3)
# print(mu3.shape)
# print(mu3)
# print(Sgm3.shape)
# print(Sgm3)
# print()
# print(test_points_combined)
# print(test_points_combined.shape)

# %% [markdown]
# # 2. The interface for the second task should look like this
#
# Parameters
# t points: t[n,d] is the d-th component of the n-th point
# mu mean
# Sgm covariance matrix
# Returns
# p p[n] is the probability density function at the n-th point
# def evaluateMultiVarGauss(t, mu, Sgm):
# This routine must be called for each class c with the same merged test points t .

# %%
import numpy as np

def evaluateMultiVarGauss(t, mu, Sgm):
    # the dimensionality of the multivariate Gaussian
    d = mu.shape[0]
    
    # the determinant of the covariance matrix
    det_Sgm = np.linalg.det(Sgm)
    
    # the inverse of the covariance matrix
    inv_Sgm = np.linalg.inv(Sgm)
    
    # the difference between each test point and the mean
    diff = t - mu
    
    # the Gauss component for each test point
    gauss_component = np.sum(np.dot(diff, inv_Sgm) * diff, axis=1)
    
    # the normalization factor
    normalization_factor = 1 / ((2 * np.pi) ** (d / 2) * np.sqrt(det_Sgm))
    
    # probability density function for each test point
    p = normalization_factor * np.exp(-0.5 * gauss_component)
    
    return p


# now we have test_points_combined from the previous
p_class1 = evaluateMultiVarGauss(test_points_combined, mu1, Sgm1)
p_class2 = evaluateMultiVarGauss(test_points_combined, mu2, Sgm2)
p_class3 = evaluateMultiVarGauss(test_points_combined, mu3, Sgm3)

print('The probabilities p(X = t|Y = c) for each test point and each class:: \n')
print(p_class1,'\n')
print(p_class2,'\n')
print(p_class3,'\n')
# print('\n',p_class1.shape)
# print()
# print(sum(p_class1) + sum(p_class2) + sum(p_class3))
# Out:
# The probabilities p(X = t|Y = c) for each test point and each class::
#
# [1.73628115e-02 7.86174736e-03 1.45942874e-02 3.18112700e-03
#  6.22520751e-03 6.71641633e-05 1.54355129e-02 1.36945430e-02
#  7.22526475e-04 6.80775450e-03 2.73435043e-14 1.75684228e-07
#  1.82939338e-14 3.85497914e-18 1.64018761e-09 3.88900810e-11
#  1.50234180e-08 2.00179500e-17 4.21537111e-08 1.54639439e-14
#  2.28318066e-12 7.38354364e-15 9.42937584e-19 2.81521637e-09
#  7.78607511e-11 2.85580913e-11 5.45692008e-26 5.14644350e-10
#  8.21796915e-08 7.38024682e-07 1.70716806e-06 1.65384727e-12
#  2.68167308e-04 2.99955734e-05 1.12973820e-12]
#
# [8.46817501e-06 1.98188301e-05 5.59406336e-05 4.72990145e-04
#  5.95393718e-09 3.04274808e-33 1.90618495e-09 6.80127736e-05
#  2.32937765e-06 5.87782844e-09 3.06975441e-02 3.65181430e-03
#  4.01870444e-02 3.02083366e-02 3.66307472e-02 1.86383273e-02
#  2.84036647e-02 2.33340790e-02 6.30004612e-03 2.16080709e-02
#  4.86273779e-02 2.61027084e-02 2.87044385e-02 1.63513217e-02
#  4.54320635e-02 4.62017647e-02 4.98143875e-03 3.75463675e-02
#  2.51041974e-02 1.77460385e-02 4.62759031e-14 3.18144461e-17
#  2.55844943e-10 1.38825867e-10 1.49021645e-18]
#
# [2.59738367e-03 2.78343299e-03 6.06149602e-04 4.72988451e-04
#  2.54108871e-04 2.84599322e-45 2.87689688e-13 1.68758924e-04
#  2.82692921e-11 5.05623307e-04 7.72192997e-10 9.78985784e-09
#  5.15330639e-09 1.01631329e-10 1.58463333e-07 1.15342612e-07
#  1.05718220e-06 6.69019792e-11 1.19638253e-08 4.90749204e-09
#  1.57059896e-08 3.63535643e-10 7.68968286e-11 7.33525050e-07
#  7.09566905e-08 3.95654770e-08 1.50546262e-13 7.80412203e-08
#  1.58651755e-06 2.50798584e-06 1.68718879e-02 1.18762067e-02
#  4.15568670e-02 2.03579998e-02 1.06211673e-02]

# %% [markdown]
# # 3. The interface for the third task should look like this
#
# Parameters
# t coordinates of the test points: t[n,d]
# pXY conditional probabilities: pXY[n,c]
# yEx exact labels of the test points: y[n]
# def calculateTestSet(t, pXY, yEx: int):
# Here pXY is a matrix whose columns are the output of evaluateMultiVarGauss.
# This routine should also print the probabilities and the actual and computed labels
# for each test point. It should also count the number of mislabelled points.

# %%
import numpy as np

def calculateTestSet(t, pXY, yEx):
    # uniform priors
    n, c = pXY.shape
    prior = 1 / c
    
    pYX_unnormalized = pXY * prior
    
    # Normalize to get proper prob
    pYX = pYX_unnormalized / np.sum(pYX_unnormalized, axis=1, keepdims=True)
    
    # Predicted class
    yPred = np.argmax(pYX, axis=1)
    
    # number of mislabeled points
    num_mislabeled = np.sum(yEx != yPred)
    
    # the results for each test point
    for i in range(len(t)):
        print(f"Test point {i+1}: True label = {yEx[i]}, Predicted label = {yPred[i]}")
        print(f"Posterior probabilities: {pYX[i]}")
    
    print(f"Number of mislabeled points: {num_mislabeled} out of {len(t)}")

# usage:
pXY_combined = np.column_stack((p_class1, p_class2, p_class3)) 
yEx_combined = np.concatenate((np.zeros(nt1), np.ones(nt2), np.ones(nt3)*2)) 
calculateTestSet(test_points_combined, pXY_combined, yEx_combined)
# Out:
# Test point 1: True label = 0.0, Predicted label = 0
# Posterior probabilities: [8.69502941e-01 4.24073201e-04 1.30072986e-01]
# Test point 2: True label = 0.0, Predicted label = 0
# Posterior probabilities: [0.73715405 0.00185831 0.26098764]
# Test point 3: True label = 0.0, Predicted label = 0
# Posterior probabilities: [0.9566024 0.0036667 0.0397309]
# Test point 4: True label = 0.0, Predicted label = 0
# Posterior probabilities: [0.77078886 0.11460578 0.11460537]
# Test point 5: True label = 0.0, Predicted label = 0
# Posterior probabilities: [9.60780648e-01 9.18913565e-07 3.92184334e-02]
# Test point 6: True label = 0.0, Predicted label = 0
# Posterior probabilities: [1.00000000e+00 4.53031488e-29 4.23736868e-41]
# Test point 7: True label = 0.0, Predicted label = 0
# Posterior probabilities: [9.99999876e-01 1.23493448e-07 1.86381661e-11]
# Test point 8: True label = 0.0, Predicted label = 0
# Posterior probabilities: [0.98300435 0.00488201 0.01211364]
# Test point 9: True label = 0.0, Predicted label = 0
# Posterior probabilities: [9.96786387e-01 3.21357350e-03 3.89998797e-08]
# Test point 10: True label = 0.0, Predicted label = 0
# Posterior probabilities: [9.30862484e-01 8.03708474e-07 6.91367127e-02]
# Test point 11: True label = 1.0, Predicted label = 1
# Posterior probabilities: [8.90739125e-13 9.99999975e-01 2.51548780e-08]
# Test point 12: True label = 1.0, Predicted label = 1
# Posterior probabilities: [4.81063085e-05 9.99949213e-01 2.68068413e-06]
# Test point 13: True label = 1.0, Predicted label = 1
# Posterior probabilities: [4.55219630e-13 9.99999872e-01 1.28233011e-07]
# Test point 14: True label = 1.0, Predicted label = 1
# Posterior probabilities: [1.27613088e-16 9.99999997e-01 3.36434709e-09]
# Test point 15: True label = 1.0, Predicted label = 1
# Posterior probabilities: [4.47760574e-08 9.99995629e-01 4.32594616e-06]
# Test point 16: True label = 1.0, Predicted label = 1
# Posterior probabilities: [2.08655206e-09 9.99993809e-01 6.18842540e-06]
# Test point 17: True label = 1.0, Predicted label = 1
# Posterior probabilities: [5.28905374e-07 9.99962253e-01 3.72185176e-05]
# Test point 18: True label = 1.0, Predicted label = 1
# Posterior probabilities: [8.57884723e-16 9.99999997e-01 2.86713604e-09]
# Test point 19: True label = 1.0, Predicted label = 1
# Posterior probabilities: [6.69095878e-06 9.99991410e-01 1.89898967e-06]
# Test point 20: True label = 1.0, Predicted label = 1
# Posterior probabilities: [7.15655758e-13 9.99999773e-01 2.27113792e-07]
# Test point 21: True label = 1.0, Predicted label = 1
# Posterior probabilities: [4.69525609e-11 9.99999677e-01 3.22986458e-07]
# Test point 22: True label = 1.0, Predicted label = 1
# Posterior probabilities: [2.82865036e-13 9.99999986e-01 1.39271233e-08]
# Test point 23: True label = 1.0, Predicted label = 1
# Posterior probabilities: [3.28498877e-17 9.99999997e-01 2.67891770e-09]
# Test point 24: True label = 1.0, Predicted label = 1
# Posterior probabilities: [1.72162816e-07 9.99954970e-01 4.48582708e-05]
# Test point 25: True label = 1.0, Predicted label = 1
# Posterior probabilities: [1.71378149e-09 9.99998436e-01 1.56181723e-06]
# Test point 26: True label = 1.0, Predicted label = 1
# Posterior probabilities: [6.18116365e-10 9.99999143e-01 8.56362162e-07]
# Test point 27: True label = 1.0, Predicted label = 1
# Posterior probabilities: [1.0954506e-23 1.0000000e+00 3.0221442e-11]
# Test point 28: True label = 1.0, Predicted label = 1
# Posterior probabilities: [1.37068725e-08 9.99997908e-01 2.07852483e-06]
# Test point 29: True label = 1.0, Predicted label = 1
# Posterior probabilities: [3.27332629e-06 9.99933534e-01 6.31931016e-05]
# Test point 30: True label = 1.0, Predicted label = 1
# Posterior probabilities: [4.15805313e-05 9.99817119e-01 1.41300672e-04]
# Test point 31: True label = 2.0, Predicted label = 2
# Posterior probabilities: [1.01173938e-04 2.74250406e-12 9.99898826e-01]
# Test point 32: True label = 2.0, Predicted label = 2
# Posterior probabilities: [1.39257199e-10 2.67883904e-15 1.00000000e+00]
# Test point 33: True label = 2.0, Predicted label = 2
# Posterior probabilities: [6.41164582e-03 6.11702883e-09 9.93588348e-01]
# Test point 34: True label = 2.0, Predicted label = 2
# Posterior probabilities: [1.47123700e-03 6.80919648e-09 9.98528756e-01]
# Test point 35: True label = 2.0, Predicted label = 2
# Posterior probabilities: [1.06366670e-10 1.40306278e-16 1.00000000e+00]
# Number of mislabeled points: 0 out of 35

# %% [markdown]
# # Modifying the code to test tied covariances as given in question

# %%
#given formula for tied cov
N = nx1 + nx2 + nx3
tied_cov = (nx1 * Sgm1 + nx2 * Sgm2 + nx3 * Sgm3) / N

p_class1_tied = evaluateMultiVarGauss(test_points_combined, mu1, tied_cov)
p_class2_tied = evaluateMultiVarGauss(test_points_combined, mu2, tied_cov)
p_class3_tied = evaluateMultiVarGauss(test_points_combined, mu3, tied_cov)

pXY_combined_tied = np.column_stack((p_class1_tied, p_class2_tied, p_class3_tied))
calculateTestSet(test_points_combined, pXY_combined_tied, yEx_combined)
# Out:
# Test point 1: True label = 0.0, Predicted label = 0
# Posterior probabilities: [9.07983250e-01 7.56087612e-05 9.19411411e-02]
# Test point 2: True label = 0.0, Predicted label = 0
# Posterior probabilities: [0.93429425 0.00321667 0.06248908]
# Test point 3: True label = 0.0, Predicted label = 0
# Posterior probabilities: [9.77036950e-01 6.15320830e-04 2.23477294e-02]
# Test point 4: True label = 0.0, Predicted label = 0
# Posterior probabilities: [0.97384213 0.01955782 0.00660005]
# Test point 5: True label = 0.0, Predicted label = 2
# Posterior probabilities: [4.64894686e-01 5.34465233e-04 5.34570849e-01]
# Test point 6: True label = 0.0, Predicted label = 0
# Posterior probabilities: [9.99409966e-01 5.66993423e-10 5.90033771e-04]
# Test point 7: True label = 0.0, Predicted label = 0
# Posterior probabilities: [9.99100572e-01 5.71200632e-05 8.42307563e-04]
# Test point 8: True label = 0.0, Predicted label = 0
# Posterior probabilities: [9.86850423e-01 7.78647078e-04 1.23709298e-02]
# Test point 9: True label = 0.0, Predicted label = 0
# Posterior probabilities: [9.74353944e-01 2.55672902e-02 7.87654918e-05]
# Test point 10: True label = 0.0, Predicted label = 2
# Posterior probabilities: [4.07570120e-01 2.26665110e-04 5.92203215e-01]
# Test point 11: True label = 1.0, Predicted label = 1
# Posterior probabilities: [1.46385193e-05 9.99985361e-01 9.27760354e-12]
# Test point 12: True label = 1.0, Predicted label = 1
# Posterior probabilities: [2.93222554e-02 9.70677396e-01 3.48687706e-07]
# Test point 13: True label = 1.0, Predicted label = 1
# Posterior probabilities: [6.98360604e-06 9.99993016e-01 1.44233705e-11]
# Test point 14: True label = 1.0, Predicted label = 1
# Posterior probabilities: [4.95416215e-07 9.99999505e-01 1.01623177e-13]
# Test point 15: True label = 1.0, Predicted label = 1
# Posterior probabilities: [1.29786087e-03 9.98702123e-01 1.60505462e-08]
# Test point 16: True label = 1.0, Predicted label = 1
# Posterior probabilities: [1.24027730e-04 9.99875970e-01 2.51727113e-09]
# Test point 17: True label = 1.0, Predicted label = 1
# Posterior probabilities: [3.08360509e-03 9.96916267e-01 1.28039208e-07]
# Test point 18: True label = 1.0, Predicted label = 1
# Posterior probabilities: [1.08413488e-06 9.99998916e-01 1.84328759e-13]
# Test point 19: True label = 1.0, Predicted label = 1
# Posterior probabilities: [1.22624319e-02 9.87737456e-01 1.12213995e-07]
# Test point 20: True label = 1.0, Predicted label = 1
# Posterior probabilities: [5.13164422e-06 9.99994868e-01 1.81621298e-11]
# Test point 21: True label = 1.0, Predicted label = 1
# Posterior probabilities: [6.32790592e-05 9.99936721e-01 1.86536077e-10]
# Test point 22: True label = 1.0, Predicted label = 1
# Posterior probabilities: [9.41391328e-06 9.99990586e-01 4.16558837e-12]
# Test point 23: True label = 1.0, Predicted label = 1
# Posterior probabilities: [2.91041324e-07 9.99999709e-01 5.43824499e-14]
# Test point 24: True label = 1.0, Predicted label = 1
# Posterior probabilities: [9.79268640e-04 9.99020679e-01 5.27146105e-08]
# Test point 25: True label = 1.0, Predicted label = 1
# Posterior probabilities: [2.80805231e-04 9.99719193e-01 2.01387304e-09]
# Test point 26: True label = 1.0, Predicted label = 1
# Posterior probabilities: [1.88635907e-04 9.99811363e-01 9.57432835e-10]
# Test point 27: True label = 1.0, Predicted label = 1
# Posterior probabilities: [2.48229430e-09 9.99999998e-01 2.62178830e-17]
# Test point 28: True label = 1.0, Predicted label = 1
# Posterior probabilities: [7.80885134e-04 9.99219108e-01 6.41240119e-09]
# Test point 29: True label = 1.0, Predicted label = 1
# Posterior probabilities: [8.59392092e-03 9.91405620e-01 4.59165537e-07]
# Test point 30: True label = 1.0, Predicted label = 1
# Posterior probabilities: [3.44675679e-02 9.65529636e-01 2.79629315e-06]
# Test point 31: True label = 2.0, Predicted label = 2
# Posterior probabilities: [2.1383304e-03 8.8679041e-12 9.9786167e-01]
# Test point 32: True label = 2.0, Predicted label = 2
# Posterior probabilities: [1.45766192e-04 1.92759669e-16 9.99854234e-01]
# Test point 33: True label = 2.0, Predicted label = 2
# Posterior probabilities: [4.08424758e-02 4.62041491e-09 9.59157520e-01]
# Test point 34: True label = 2.0, Predicted label = 2
# Posterior probabilities: [3.62616693e-02 2.49923353e-10 9.63738330e-01]
# Test point 35: True label = 2.0, Predicted label = 2
# Posterior probabilities: [5.86131136e-05 1.23288171e-16 9.99941387e-01]
# Number of mislabeled points: 2 out of 35

# %% [markdown]
# # Testing the methodology on the iris data set

# %%
from sklearn.datasets import load_iris
import numpy as np

def getIrisData():
    iris = load_iris()
    data = iris.data
    target = iris.target
    
    # Splitting the data into training and test sets as per the instructions
    x = np.concatenate([data[:40, :], data[50:90, :], data[100:140, :]])  #training data
    t = np.concatenate([data[40:50, :], data[90:100, :], data[140:150, :]])  #testing data
    y_train = np.concatenate([target[:40], target[50:90], target[100:140]])   #labels corresponding to training data
    y_test = np.concatenate([target[40:50], target[90:100], target[140:150]])   #labels corresponding to testing data
    
    return x, t, y_train, y_test

# Loading the data
x, t, y_train, y_test = getIrisData()

# %%
def calculateMeanAndCov(x, y, class_label):
    class_data = x[y == class_label, :]
    mean = np.mean(class_data, axis=0)
    cov = np.cov(class_data, rowvar=False)
    return mean, cov

# Class means and covariances
means = []
covariances = []
for class_label in np.unique(y_train):
    mean, cov = calculateMeanAndCov(x, y_train, class_label)
    means.append(mean)
    covariances.append(cov)

# %%
p_classes = []
for i, (mean, cov) in enumerate(zip(means, covariances)):
    p = evaluateMultiVarGauss(t, mean, cov)
    p_classes.append(p)

pXY = np.column_stack(p_classes)
print('The conditional probabilities: pXY[n,c] \n\n',pXY)
print('\n',pXY.shape)
# Out:
# The conditional probabilities: pXY[n,c]
#
#  [[7.81435194e+000 5.88902311e-023 9.35547567e-036]
#  [2.93126805e-003 1.73532119e-012 4.79357840e-026]
#  [2.45619345e+000 1.70664995e-019 1.93466684e-029]
#  [4.81174613e-003 3.58520997e-018 6.64854132e-029]
#  [9.87470311e-002 6.31867093e-021 8.39767713e-030]
#  [3.45674864e+000 2.01425700e-016 2.61432439e-029]
#  [3.52940179e+000 4.57657405e-026 8.55244329e-036]
#  [9.29964603e+000 5.79339655e-019 1.29804288e-029]
#  [1.12524756e+001 1.12468803e-025 4.38094192e-038]
#  [1.57261747e+001 9.24900533e-021 1.06527756e-033]
#  [7.13615519e-074 2.40751868e-001 1.31807440e-002]
#  [3.98144515e-086 2.44508165e+000 1.83458137e-002]
#  [8.29902570e-060 3.92526536e+000 3.08060272e-004]
#  [3.39890017e-036 3.67453462e-001 5.59130953e-006]
#  [1.93728765e-069 3.33068754e+000 9.94926107e-003]
#  [2.67930372e-064 4.88100376e-001 6.35497100e-004]
#  [2.96056406e-068 2.71070381e+000 3.38968338e-003]
#  [8.99168518e-072 3.77762450e+000 5.22602840e-004]
#  [1.32502087e-032 9.19610454e-003 3.95785623e-008]
#  [2.18262715e-065 3.97986533e+000 2.33053061e-003]
#  [9.43493717e-192 1.65374215e-008 4.55493468e-001]
#  [1.36864782e-161 1.09930077e-009 5.74628822e-003]
#  [4.47325197e-136 2.04944426e-003 9.08514382e-001]
#  [1.45954928e-197 1.00979403e-005 1.02991327e+000]
#  [6.99204941e-204 2.91398336e-009 3.00237797e-001]
#  [1.91631676e-166 6.38674374e-009 6.81660862e-002]
#  [5.75505316e-133 2.35510388e-004 1.95355696e-001]
#  [1.79928931e-143 4.84677519e-003 9.51533704e-001]
#  [4.95621356e-174 6.35435188e-006 2.59190286e-001]
#  [8.45991244e-128 7.32798211e-002 5.89810146e-001]]
#
#  (30, 3)

# %%
calculateTestSet(t, pXY, y_test)
# Out:
# Test point 1: True label = 0, Predicted label = 0
# Posterior probabilities: [1.00000000e+00 7.53616315e-24 1.19721709e-36]
# Test point 2: True label = 0, Predicted label = 0
# Posterior probabilities: [9.99999999e-01 5.92003584e-10 1.63532584e-23]
# Test point 3: True label = 0, Predicted label = 0
# Posterior probabilities: [1.00000000e+00 6.94835316e-20 7.87668757e-30]
# Test point 4: True label = 0, Predicted label = 0
# Posterior probabilities: [1.00000000e+00 7.45095414e-16 1.38173153e-26]
# Test point 5: True label = 0, Predicted label = 0
# Posterior probabilities: [1.00000000e+00 6.39884649e-20 8.50423252e-29]
# Test point 6: True label = 0, Predicted label = 0
# Posterior probabilities: [1.00000000e+00 5.82702768e-17 7.56295775e-30]
# Test point 7: True label = 0, Predicted label = 0
# Posterior probabilities: [1.00000000e+00 1.29669965e-26 2.42319911e-36]
# Test point 8: True label = 0, Predicted label = 0
# Posterior probabilities: [1.00000000e+00 6.22969576e-20 1.39579816e-30]
# Test point 9: True label = 0, Predicted label = 0
# Posterior probabilities: [1.00000000e+00 9.99502744e-27 3.89331386e-39]
# Test point 10: True label = 0, Predicted label = 0
# Posterior probabilities: [1.00000000e+00 5.88128106e-22 6.77391406e-35]
# Test point 11: True label = 1, Predicted label = 1
# Posterior probabilities: [2.81025550e-73 9.48093536e-01 5.19064640e-02]
# Test point 12: True label = 1, Predicted label = 1
# Posterior probabilities: [1.61622179e-86 9.92552728e-01 7.44727172e-03]
# Test point 13: True label = 1, Predicted label = 1
# Posterior probabilities: [2.11409259e-60 9.99921525e-01 7.84752288e-05]
# Test point 14: True label = 1, Predicted label = 1
# Posterior probabilities: [9.24973854e-36 9.99984784e-01 1.52161431e-05]
# Test point 15: True label = 1, Predicted label = 1
# Posterior probabilities: [5.79915676e-70 9.97021747e-01 2.97825285e-03]
# Test point 16: True label = 1, Predicted label = 1
# Posterior probabilities: [5.48210979e-64 9.98699713e-01 1.30028740e-03]
# Test point 17: True label = 1, Predicted label = 1
# Posterior probabilities: [1.09081138e-68 9.98751081e-01 1.24891917e-03]
# Test point 18: True label = 1, Predicted label = 1
# Posterior probabilities: [2.37991929e-72 9.99861677e-01 1.38322523e-04]
# Test point 19: True label = 1, Predicted label = 1
# Posterior probabilities: [1.44084396e-30 9.99995696e-01 4.30382145e-06]
# Test point 20: True label = 1, Predicted label = 1
# Posterior probabilities: [5.48096383e-66 9.99414762e-01 5.85237565e-04]
# Test point 21: True label = 2, Predicted label = 2
# Posterior probabilities: [2.07136600e-191 3.63066039e-008 9.99999964e-001]
# Test point 22: True label = 2, Predicted label = 2
# Posterior probabilities: [2.38179414e-159 1.91306199e-007 9.99999809e-001]
# Test point 23: True label = 2, Predicted label = 2
# Posterior probabilities: [4.91261770e-136 2.25074202e-003 9.97749258e-001]
# Test point 24: True label = 2, Predicted label = 2
# Posterior probabilities: [1.41714358e-197 9.80455501e-006 9.99990195e-001]
# Test point 25: True label = 2, Predicted label = 2
# Posterior probabilities: [2.32883714e-203 9.70558456e-009 9.99999990e-001]
# Test point 26: True label = 2, Predicted label = 2
# Posterior probabilities: [2.81124631e-165 9.36938513e-008 9.99999906e-001]
# Test point 27: True label = 2, Predicted label = 2
# Posterior probabilities: [2.94238849e-132 1.20409497e-003 9.98795905e-001]
# Test point 28: True label = 2, Predicted label = 2
# Posterior probabilities: [1.88135303e-143 5.06783157e-003 9.94932168e-001]
# Test point 29: True label = 2, Predicted label = 2
# Posterior probabilities: [1.91214421e-173 2.45155642e-005 9.99975484e-001]
# Test point 30: True label = 2, Predicted label = 2
# Posterior probabilities: [1.27583177e-127 1.10512637e-001 8.89487363e-001]
# Number of mislabeled points: 0 out of 30
